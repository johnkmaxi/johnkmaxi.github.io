# %% [markdown]
# # How to build time series models
# In this post, I will demonstrate how to load time series data, normalize the data, and build a model to predict future values of the time series. For this example, I'm going to use historical Apple stock data. You can get the data yourself by getting a Quandl API key. See this [post](https://johnkmaxi.github.io/blog/2018/04/22/Bollinger-Band-Trading-with-Apple-Stock) for a the nuts and bolts of the quandl_stocks function. The first thing we'll do is grab the data.
#
# # Import data

# %%
import quandlkey as qk
data = qk.quandl_stocks('AAPL') # data from 2000/1/1 to today
data.head()
# Out:
#             WIKI/AAPL - Open  WIKI/AAPL - High  WIKI/AAPL - Low  \
# Date
# 2000-01-03            104.87            112.50           101.69
# 2000-01-04            108.25            110.62           101.19
# 2000-01-05            103.75            110.56           103.00
# 2000-01-06            106.12            107.00            95.00
# 2000-01-07             96.50            101.00            95.50
#
#             WIKI/AAPL - Close  WIKI/AAPL - Volume  WIKI/AAPL - Ex-Dividend  \
# Date
# 2000-01-03             111.94           4783900.0                      0.0
# 2000-01-04             102.50           4574800.0                      0.0
# 2000-01-05             104.00           6949300.0                      0.0
# 2000-01-06              95.00           6856900.0                      0.0
# 2000-01-07              99.50           4113700.0                      0.0
#
#             WIKI/AAPL - Split Ratio  WIKI/AAPL - Adj. Open  \
# Date
# 2000-01-03                      1.0               3.369314
# 2000-01-04                      1.0               3.477908
# 2000-01-05                      1.0               3.333330
# 2000-01-06                      1.0               3.409475
# 2000-01-07                      1.0               3.100399
#
#             WIKI/AAPL - Adj. High  WIKI/AAPL - Adj. Low  \
# Date
# 2000-01-03               3.614454              3.267146
# 2000-01-04               3.554053              3.251081
# 2000-01-05               3.552125              3.309234
# 2000-01-06               3.437748              3.052206
# 2000-01-07               3.244977              3.068270
#
#             WIKI/AAPL - Adj. Close  WIKI/AAPL - Adj. Volume
# Date
# 2000-01-03                3.596463              133949200.0
# 2000-01-04                3.293170              128094400.0
# 2000-01-05                3.341362              194580400.0
# 2000-01-06                3.052206              191993200.0
# 2000-01-07                3.196784              115183600.0

# %% [markdown]
# There are several columns of data available to work with and using some combination of them is likely to produce the best results. For this demonstration, we're going to use just one column, the Adjusted Close.
#
# I have come up with several different models using different transforms of the features. I am not sure which one is "correct" or why the transformations have such different effects on model performance.
# 1. No transformation `close = data['WIKI/AAPL - Adj. Close']`
# 2. Daily Return
#     - `close = close = data['WIKI/AAPL - Adj. Close']`
#     - `close = close/close.shift(1)-1`
# 3. Ratio of yesterday's daily return to today's daily return
#     - `close = close = data['WIKI/AAPL - Adj. Close']`
#     - `close = close/close.shift(1)`
#     - `close = close.shift(1)/close-1`

# %%
# Only need to work with the adj. close
close = data['WIKI/AAPL - Adj. Close']

# %%
close = close/close.shift(1)

# %% [markdown]
# The problem we are trying to solve in the demonstration is to predict the stock price of a given day by using the price from the previous two days. To make this problem more conducive for use with a machine learning model we need to do some data normalizing. We will do this in two ways. 1) We'll first divide the adjusted closing price by the first adjusted close price of the first day we have on record. This will give us the cumulative return of the stock as a multiple of the starting price. 2) We'll transform these values into percent change from the previous day. In this way, we'll be able to predict how much the stock will increase or decrease in value each day, regardless of the actual share price.

# %% [markdown]
# # Convert Adj. Close to % Change from Previous Day

# %%
# convert the price to a % change from the previous day
close = (close.shift(1)/close)-1

# %% [markdown]
# # Create a time lag DataFrame
#
# In this example, we will use the previous 2 days daily return to predict the predict the daily return for the next day. The primary reason for making the model this way is to allow for easy visualization.

# %%
# use close to shift(1)
close = pd.concat([close,close.shift(1),close.shift(2)],axis=1)
close.columns = ['Y','X1','X2']
close.dropna(inplace=True)
close.head()
# Out:
#                    Y        X1        X2
# Date
# 2000-01-07 -0.127851  0.110757 -0.097538
# 2000-01-10  0.066119 -0.127851  0.110757
# 2000-01-11  0.035372  0.066119 -0.127851
# 2000-01-12  0.009356  0.035372  0.066119
# 2000-01-13 -0.152834  0.009356  0.035372

# %% [markdown]
# # Visualize the data
#
# Figue 1 - The daily change over time.
# Figure 2 - Scatter plot of X1 and X2 vs Y.
# Since we only have two features, we can visualize the returns using a scatter plot.

# %%
# %matplotlib inline
fig, ax = plt.subplots(2, figsize=(7,9))
close['Y'].plot(kind='line', ax=ax[0])
ax[1].scatter(close['X1'],close['X2'],c=['r' if x<0 else 'g' for x in close['Y']])
ax[1].set_xlim(-0.2,0.2) # set the plot limits to zoom in on the bulk of the data
ax[1].set_ylim(-0.2,0.2)
ax[0].set_title('% Change from Previous Day')
ax[0].set_ylabel('% Change')
ax[1].set_title('One Day Ago vs Two Days Ago')
ax[1].set_xlabel('X1')
ax[1].set_ylabel('X2')
plt.tight_layout()

# %% [markdown]
# # Split into train and test set

# %%
split_index = int(len(close)*0.6)
train = close.iloc[:split_index,:]
test = close.iloc[split_index:,:]
ytrain = train['Y']
Xtrain = train.drop('Y', axis=1)
ytest = test['Y']
Xtest = test.drop('Y', axis=1)

# %% [markdown]
# # Train the Model
#
# For simplicity, we'll use a linear regression model.

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(Xtrain, ytrain)
print(lr.coef_, lr.intercept_)
# Out:
# [-0.61253731 -0.28064298] 0.00208474021198

# %% [markdown]
# # Score the model

# %%
from sklearn.metrics import mean_squared_error, r2_score
# the R^2 value, 1.0 = perfect predictions, 0 = constant value, < 0 = worse than constant prediction
print('R^2: ', lr.score(Xtest, ytest))
# MSE
print('MSE: ', mean_squared_error(ytest,lr.predict(Xtest)))
# Out:
# R^2:  0.302889946379
# MSE:  0.000338446670654

# %%
# Baseline regressors
base_predictor = [np.mean(ytrain) for x in ytest]
print('R^2: ', r2_score(ytest, base_predictor))
print('MSE: ', mean_squared_error(ytest, base_predictor))
# Out:
# R^2:  -0.00143220646302
# MSE:  0.000486194962191

# %% [markdown]
# The R^2 value indicates that the model actually does worse than simply predicting the mean of y for every prediction. A negative R^2 value can also arise when when the model is not fitted on the data being tested, as is the case here. A linear model is clearly not a good choice for modeling the data used here.

# %% [markdown]
# # Plot the Predictions

# %%
fig, ax = plt.subplots(1, figsize=(16,9))
#close['Y'].plot(kind='line', ax=ax)
ytest.plot(kind='line',ax=ax)
#ax.plot(close.index, lr.predict(close.loc[:,['X1','X2']]));
ax.plot(Xtest.index, lr.predict(Xtest.values))

# %% [markdown]
# # Features vs Target, Target Distribution

# %%
fig, ax = plt.subplots(2,2,figsize=(16,9))
ax[0][0].scatter(close['X1'],close['Y'])
ax[0][0].set_title('X1 vs Y')
ax[0][1].scatter(close['X2'],close['Y'])
ax[0][1].set_title('X2 vs Y')
ax[1][0].hist(lr.predict(close.loc[:,['X1','X2']]),50);
ax[1][0].set_title('Prediction Distribution')
ax[1][1].hist(close['Y'],50);
ax[1][1].set_title('Actual Distribution');
